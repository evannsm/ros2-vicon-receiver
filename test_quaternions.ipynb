# %%
from scipy.spatial.transform import Rotation as R
import math as m

# %%
quat1 = [0.7924052476882935,
        0.036349520087242126,
        -0.6064128279685974,
        0.05510122328996658]


quat2 = [0.8088864684104919,
         0.5876243710517883,
         0.00795299094170332,
         0.018360484391450882]


quat3 = [0.6886937022209167,
         0.028059812262654305,
         -0.014154897071421146,
         0.7243709564208984]



quatX = [0.8074026107788086, 0.5897899866104126, -0.011139865964651108,-0.011166829615831375]

# %%
r = R.from_quat(quatX, scalar_first=True)
roll, pitch, yaw = r.as_euler('xyz', degrees=True) #(-0.005448548314084914, -0.6230168375148765, -0.01056768867977631) AKA neg pitch when tilting forward to go front to +X
print(f"{roll}, {pitch}, {yaw}")
# Out:
# 72.29892853132763, -0.27596877616267335, -1.7863695413663185

# %% [markdown]
# # test on data

# %% [markdown]
# ### Negative Pitch Tilt Forward

# %%
sim_negpitch_goforward = [0.9518511295318604, -0.004212579224258661, -0.3064756989479065, -0.005864466540515423]
roll, pitch, yaw = R.from_quat(sim_negpitch_goforward, scalar_first=True).as_euler('xyz', degrees=True) #(-0.005448548314084914, -0.6230168375148765, -0.01056768867977631) AKA neg pitch when tilting forward to go front to +X
print(f"(roll,pitch,yaw)={roll,pitch,yaw}")
# Out:
# (roll,pitch,yaw)=(np.float64(-0.3121788228701856), np.float64(-35.6962353551902), np.float64(-0.6054839605593659))

# %%
hardware_negpitch_goforward_oldVerified = [0.8088037967681885, 0.026748254895210266, -0.5844698548316956, 0.05929585173726082]
hardware_negpitch_goforward = [0.8104275465011597, -0.03927755728363991, -0.5821389555931091, 0.052713338285684586]
roll, pitch, yaw = R.from_quat(hardware_negpitch_goforward, scalar_first=True).as_euler('xyz', degrees=True) #(-0.005448548314084914, -0.6230168375148765, -0.01056768867977631) AKA neg pitch when tilting forward to go front to +X
print(f"(roll,pitch,yaw)={roll,pitch,yaw}")
# Out:
# (roll,pitch,yaw)=(np.float64(-21.394618888316174), np.float64(-69.95471332941177), np.float64(22.50018858174337))

# %% [markdown]
# ### Positive Roll Tilt CW to +Y

# %%
sim_posroll_goright = [0.9685525298118591, 0.24774451553821564, -0.022614458575844765, -0.004153035115450621]
roll, pitch, yaw = R.from_quat(sim_posroll_goright, scalar_first=True).as_euler('xyz', degrees=True)  #(0.5012406346841017, -0.04176093567396901, -0.019268071582676516) AKA pos roll when tilting CW from the back to go right to +Y
print(f"(roll,pitch,yaw)={roll,pitch,yaw}")
# Out:
# (roll,pitch,yaw)=(np.float64(28.71897288785774), np.float64(-2.3927253626357414), np.float64(-1.103979181043316))

# %%
hardware_posroll_goright_oldVerified = [0.8066073656082153, 0.5910258293151855, -0.008194857276976109, -0.0024253912270069122]
hardware_posroll_goright = [0.8078269362449646, 0.5840032696723938, -0.031180821359157562, 0.07337295264005661]

roll, pitch, yaw = R.from_quat(hardware_posroll_goright, scalar_first=True).as_euler('xyz', degrees=True)
print(f"(roll,pitch,yaw)={roll,pitch,yaw}")
# Out:
# (roll,pitch,yaw)=(np.float64(71.40344943109005), np.float64(-7.820931196217109), np.float64(4.755103976242307))

# %% [markdown]
# ### Positive Yaw Rotate CCW About Z
# REMEMBER: POSITIVE Z IS POINTING DOWN

# %%
hardware_posyaw_goCCW_oldVerified = [0.7167863249778748, 0.0040621510706841946, 0.0057961419224739075, 0.6972570419311523]
hardware_posyaw_goCCW = [-0.6598996520042419, -0.033431120216846466, 0.02025083638727665, -0.7503364682197571]

roll, pitch, yaw = R.from_quat(hardware_posyaw_goCCW, scalar_first=True).as_euler('xyz', degrees=True)
print(f"(roll,pitch,yaw)={roll,pitch,yaw}")
# Out:
# (roll,pitch,yaw)=(np.float64(0.7891750165772257), np.float64(-4.41018180761443), np.float64(97.30818781494186))

# %% [markdown]
# ## New Data for Confirmation

# %%
q = [0.8040963411331177, 0.5921547412872314, -0.03682420775294304, -0.03776012733578682]
roll, pitch, yaw = R.from_quat(q, scalar_first=True).as_euler('xyz', degrees=True)
print(f"(roll,pitch,yaw)={roll,pitch,yaw}")
# Out:
# (roll,pitch,yaw)=(np.float64(72.78101213833517), np.float64(-0.8308605724545417), np.float64(-5.989591194161727))
